# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.offline as py

# %%
data=pd.read_csv("insurance.csv")
data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1338, step=1)

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
#      age   sex   bmi  children smoker     region  expenses
# 581   19  male  30.6         0     no  northwest   1639.56

# %%
data[data.duplicated()].shape
# Out:
# (1, 7)

# %%
datas=data.drop_duplicates()
datas
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1337 rows x 7 columns]

# %%
datas.shape
# Out:
# (1337, 7)

# %%
datas.describe()
# Out:
#                age          bmi     children      expenses
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.665520     1.095737  13279.121638
# std      14.044333     6.100664     1.205571  12110.359657
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4746.340000
# 50%      39.000000    30.400000     1.000000   9386.160000
# 75%      51.000000    34.700000     2.000000  16657.720000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
datas.corr()
# Out:
#                age       bmi  children  expenses
# age       1.000000  0.109414  0.041536  0.298308
# bmi       0.109414  1.000000  0.012641  0.198637
# children  0.041536  0.012641  1.000000  0.067389
# expenses  0.298308  0.198637  0.067389  1.000000

# %%
datas.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
object_datas_list=[column for column in datas if datas[column].dtypes=='object']
object_datas_list
# Out:
# ['sex', 'smoker', 'region']

# %%
datas.nunique()
# Out:
# age           47
# sex            2
# bmi          275
# children       6
# smoker         2
# region         4
# expenses    1337
# dtype: int64

# %%
corelation=datas.corr()
sns.heatmap(corelation,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.set_style(style='white')
sns.pairplot(datas)

# %%
sns.set_style(style='white')
sns.pairplot(datas, hue='sex')
plt.show()

# %%
sns.boxplot(x='region',y='expenses', data=datas);

# %%
# let's check the types
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (20, 6)
sns.countplot(datas['age'], palette = 'PuRd')
plt.title('Different Types of Age', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (20, 6)
sns.countplot(datas['sex'], palette = 'spring')
plt.title('Different Types of Sex', fontsize = 20)
plt.show()


plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (20, 6)
sns.countplot(datas['children'], palette = 'cool')
plt.title('Different Types of Children', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (20, 6)
sns.countplot(datas['smoker'], palette = 'spring')
plt.title('Different Types of Smoker', fontsize = 20)
plt.show()

plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (20, 6)
sns.countplot(datas['region'], palette = 'cool')
plt.title('Different Types of Region ', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
age = datas['age'].value_counts()
sex = datas['sex'].value_counts()
children = datas['children'].value_counts()
smoker = datas['smoker'].value_counts()
region = datas['region'].value_counts()



label_age = age.index
size_age = age.values

label_sex = sex.index
size_sex = sex.values

label_children = children.index
size_children = children.values

label_smoker = smoker.index
size_smoker = smoker.values

label_region = region.index
size_region = region.values

colors = []
trace = go.Pie(
         labels = label_age, values = size_age, marker = dict(colors = colors), name = 'Age', hole = 0.3)

colors2 = ['aqua', 'gold']
trace2 = go.Pie(labels = label_sex, values = size_sex, marker = dict(colors = colors2), name = 'Sex',
                hole = 0.3)

colors3 = []
trace3 = go.Pie(
         labels = label_children, values = size_children, marker = dict(colors = colors), name = 'Children', hole = 0.3)

colors4 = []
trace4 = go.Pie(
         labels = label_smoker, values = size_smoker, marker = dict(colors = colors), name = 'Smoker', hole = 0.3)

colors5 = []
trace5 = go.Pie(
         labels = label_region, values = size_region, marker = dict(colors = colors), name = 'Region', hole = 0.3)

df = [trace]
df2 = [trace2]
df3 = [trace3]
df4 = [trace4]
df5 = [trace5]

layout1 = go.Layout(
           title = 'Age')
layout2 = go.Layout(
           title = 'Sex')
layout3 = go.Layout(
           title = 'Children')
layout4 = go.Layout(
           title = 'Smoker')
layout5 = go.Layout(
           title = 'Region')

fig = go.Figure(data = df, layout = layout1)
fig2 = go.Figure(data = df2, layout = layout2)
fig3 = go.Figure(data = df3, layout = layout3)
fig4 = go.Figure(data = df4, layout = layout4)
fig5 = go.Figure(data = df5, layout = layout5)


py.iplot(fig)
py.iplot(fig2)
py.iplot(fig3)
py.iplot(fig4)
py.iplot(fig5)
# Out:
# <div>                            <div id="cafea7f9-07f8-416f-b5f6-bb7b9289b398" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cafea7f9-07f8-416f-b5f6-bb7b9289b398")) {                    Plotly.newPlot(                        "cafea7f9-07f8-416f-b5f6-bb7b9289b398",                        [{"hole":0.3,"labels":[18,19,20,51,45,46,47,48,50,52,28,54,21,27,26,49,25,24,23,22,53,42,44,43,41,40,31,30,29,56,34,33,32,57,55,35,59,58,36,39,38,37,60,61,62,63,64],"marker":{"colors":[]},"name":"Age","type":"pie","values":[69,67,29,29,29,29,29,29,29,29,28,28,28,28,28,28,28,28,28,28,28,27,27,27,27,27,27,27,27,26,26,26,26,26,26,25,25,25,25,25,25,25,23,23,23,23,22]}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color
# ...

# %%
trace = go.Scatter3d(
    x = datas['age'],
    y = datas['bmi'],
    z = datas['expenses'],
    mode = 'markers',
    marker = dict(
         size = 10,
         color = datas['age']
    )
)

datas = [trace]

layout = go.Layout(
    title = 'Age vs Bmi vs Expenses',
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0  
    ),
    scene = dict(
            xaxis = dict(title  = 'Age'),
            yaxis = dict(title  = 'Bmi'),
            zaxis = dict(title  = 'Expenses')
        )
    
)
fig = go.Figure(data = datas, layout=layout)
py.iplot(fig)
# Out:
# <div>                            <div id="f1975093-5620-4dab-b5cc-04a9b2e82167" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1975093-5620-4dab-b5cc-04a9b2e82167")) {                    Plotly.newPlot(                        "f1975093-5620-4dab-b5cc-04a9b2e82167",                        [{"marker":{"color":[19,18,28,33,32,31,46,37,37,60,25,62,23,56,27,19,52,23,56,30,60,30,18,34,37,59,63,55,23,31,22,18,19,63,28,19,62,26,35,60,24,31,41,37,38,55,18,28,60,36,18,21,48,36,40,58,58,18,53,34,43,25,64,28,20,19,61,40,40,28,27,31,53,58,44,57,29,21,22,41,31,45,22,48,37,45,57,56,46,55,21,53,59,35,64,28,54,55,56,38,41,30,18,61,34,20,19,26,29,63,54,55,37,21,52,60,58,29,49,37,44,18,20,44,47,26,19,52,32,38,59,61,53,19,20,22,19,22,54,22,34,26,34,29,30,29,46,51,53,
# ...

# %%
sns.displot(kind='kde', x='smoker', y = 'expenses', hue='sex', data=data, aspect=2);

# %%
factors=['age', 'sex', 'bmi', 'children', 'expenses']
data.groupby('sex')[factors].mean()
# Out:
#               age        bmi  children      expenses
# sex
# female  39.503021  30.379758  1.074018  12569.578897
# male    38.917160  30.945266  1.115385  13956.751420

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data.sex = le.fit_transform(data.sex)
data.smoker = le.fit_transform(data.smoker)
data.region = le.fit_transform(data.region)

# %%
x=data.drop(['expenses'],axis=1)
x
# Out:
#       age  sex   bmi  children  smoker  region
# 0      19    0  27.9         0       1       3
# 1      18    1  33.8         1       0       2
# 2      28    1  33.0         3       0       2
# 3      33    1  22.7         0       0       1
# 4      32    1  28.9         0       0       1
# ...   ...  ...   ...       ...     ...     ...
# 1333   50    1  31.0         3       0       1
# 1334   18    0  31.9         0       0       0
# 1335   18    0  36.9         0       0       2
# 1336   21    0  25.8         0       0       3
# 1337   61    0  29.1         0       1       1
#
# [1338 rows x 6 columns]

# %%
y=data.expenses
y
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# 1337    29141.36
# Name: expenses, Length: 1338, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
model= LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([ 8.48808237e+03,  1.04619341e+04,  1.16286178e+04,  3.36192962e+04,
#         1.47879808e+04, -1.44287636e+03,  2.79480954e+03,  1.43425604e+04,
#         2.34788879e+04, -1.95521952e+01,  4.40506653e+03,  8.49008729e+03,
#         2.88890790e+04,  3.48563951e+03,  5.70296541e+03,  3.18813498e+03,
#         1.41366266e+04,  2.74583655e+04,  1.04718520e+03,  1.71773970e+04,
#         2.52150203e+04,  1.05819247e+04,  3.55500487e+04,  7.24099280e+03,
#         3.67452481e+03,  3.42751098e+04,  6.74111682e+03,  1.14108767e+04,
#         1.12741789e+04,  1.12616161e+04,  1.13889396e+04,  3.44418847e+03,
#         2.92164732e+04,  1.25256108e+03,  8.27714150e+03,  1.05246396e+04,
#         7.10159998e+03,  1.06432345e+04,  7.12738449e+03,  3.29750247e+04,
#         1.49855651e+03,  7.50720884e+03,  1.03276737e+04,  1.22540483e+04,
#         2.25274446e+03,  1.14907937e+04,  6.59056580e+03,  8.46717054e+03,
# ...

# %%
print("Training Accuracy :", model.score(X_train, y_train))
print("Testing Accuracy :", model.score(X_test, y_test))
# Out:
# Training Accuracy : 0.7479138254552196
# Testing Accuracy : 0.7610792088781063

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
model1 = DecisionTreeRegressor()
model1.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model1.predict(X_test)
y_pred
# Out:
# array([11837.16, 14478.33,  4670.64, 22493.66, 21797.  , 39556.49,
#         1842.52, 23244.79, 14451.84, 10435.07, 38245.59, 43921.18,
#         4320.41, 26018.95,  3385.4 , 10231.5 , 16297.85,  7419.48,
#         5400.98, 17468.98,  2566.47, 21774.32,  5699.84, 17929.3 ,
#         3757.84,  1981.58, 12928.79, 41919.1 , 13470.8 ,  1632.56,
#        12638.2 ,  3392.98,  2690.11, 19442.35,  3213.62,  6748.59,
#        37165.16,  3292.53,  2104.11,  8547.69, 11070.54, 23563.02,
#         1622.19, 10269.46,  4992.38, 17929.3 ,  2855.44, 10579.71,
#        13937.67,  8023.14,  5124.19,  6781.35,  9095.07, 11741.73,
#        10118.42, 30063.58, 10214.64, 19719.69,  8232.64, 32108.66,
#         1728.9 ,  2104.11, 12231.61, 10269.46, 11289.11,  3392.98,
#        13129.6 ,  5693.43, 37701.88, 16796.41, 14001.13,  6799.46,
#         8534.67,  1832.09,  3062.51,  4032.24,  3393.36, 18246.5 ,
#         8068.19, 16776.3 , 33900.65, 20781.49,  9288.03, 44423.8 ,
# ...

# %%
print("Training Accuracy :", model1.score(X_train, y_train))
print("Testing Accuracy :", model1.score(X_test, y_test))
# Out:
# Training Accuracy : 0.9984188667660981
# Testing Accuracy : 0.5691971527487483

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
model2 = RandomForestRegressor()
model2.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model2.predict(X_test)
y_pred
# Out:
# array([ 2354.8066    ,  2654.3014    , 41556.85      ,  5336.3395    ,
#        23194.1346    , 42813.3466    , 13091.5495    ,  2118.1325    ,
#        13291.2998    ,  6530.9905    , 10465.0264    ,  2567.849     ,
#         4888.6785    , 22685.429     ,  5969.241     ,  3128.9336    ,
#        45418.8533    ,  9122.2493    , 19784.0141    , 13104.7451    ,
#         1711.454     , 11534.5158    ,  6394.8403    ,  6618.2879    ,
#         6775.3656    , 14245.2529    , 43290.0974    ,  5457.8934    ,
#        13794.5703    , 11311.852     , 13433.0273    ,  6895.2512    ,
#         2424.8781    , 12566.0963    , 12836.0063    ,  6223.6792    ,
#        14209.0672    , 11421.1894    , 11347.3254    , 43808.8874    ,
#         6256.5029    ,  1924.5654    ,  4787.2039    ,  1737.6886    ,
#        47318.9939    , 14230.4322    ,  7603.2148    ,  8563.2781    ,
#        39310.4639    , 14375.4679    ,  1865.3191    , 12745.8805    ,
# ...

# %%
print("Training Accuracy :", model2.score(X_train, y_train))
print("Testing Accuracy :", model2.score(X_test, y_test))
# Out:
# Training Accuracy : 0.9770260279358436
# Testing Accuracy : 0.815582066312139
